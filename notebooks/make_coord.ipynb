# %%
import numpy as np
import os

# %%
PATH_SOURCE = "/home/jbassham/jack/thesis-rough/data/regrid/sh"

# %%
fnam = "motion_ppv4_latlon_sh_1992_2020.npz"
data = np.load(os.path.join(PATH_SOURCE, fnam))

t1 = data['time']
lat1 = data['lat']
lon1 = data['lon']

# %%
fnam = "wind_JRA55_latlon_sh_1992_2020.npz"
data = np.load(os.path.join(PATH_SOURCE, fnam))

t2 = data['time']
lat2 = data['lat']
lon2 = data['lon']

# %%
fnam = "con_nimbus7_latlon_sh_1992_2020.npz"
data = np.load(os.path.join(PATH_SOURCE, fnam))

t3 = data['time']
lat3 = data['lat']
lon3 = data['lon']

# %%
# Check that dates line up
if t1.all() == t2.all():
    print('t1=t2')

    if t2.all() == t3.all():
        print('t2=t3')
    else: print('t2 != t3')

else: print('t1 != t2')
# Out:
# t1=t2
# t2=t3

# %%
# Check that dates line up
if t1.all() == t3.all():
    print('t1=t3')
else: print('t1 != t3')
# Out:
# t1=t3

# %%
# Check that grid lines up
if lat1.all() == lat2.all():
    print('lat1=lat2')

    if lat1.all() == lat2.all():
        print('lat2=lat3')
    else: print('lat2 != lat3')

else: print('lat1 != lat2')
# Out:
# lat1=lat2
# lat2=lat3

# %%
# Check that grid lines up
if lon1.all() == lon2.all():
    print('lon1=lon2')

    if lon2.all() == lon3.all():
        print('lon2=lon3')
    else: print('lon2 != lon3')

else: print('lon1 != lon2')
# Out:
# lon1=lon2
# lon2=lon3

# %%
def assert_equal(coord_dict):
    """
    Asserts arrays are equal
    
    Takes input 'coord_dict' mapping name to array
        Example: {"a": a, "b": b, "c": c}

    If arrays are equal, program continues.
    If not, program strops and value error is raised with print statement.
    """

    # Pull variable names from dict keys
    names = list(coord_dict.keys())
    for i in range (len(names)):
        for j in range(i + 1, len(names)):
            a, b = names[i] ,names[j]
            if not np.array_equal(coord_dict[a], coord_dict[b]):
                raise ValueError(f"ERROR: {a} and {b} not equal")

# %%
np.array_equal(t1, t3)
# Out:
# False

# %%
np.array_equal(t1, t2)
# Out:
# True

# %%
np.array_equal(t2, t3)
# Out:
# False

# %%
print(t1)
# Out:
# ['1992-01-01T00:00:00.000000' '1992-01-02T00:00:00.000000'
#  '1992-01-03T00:00:00.000000' ... '2020-12-29T00:00:00.000000'
#  '2020-12-30T00:00:00.000000' '2020-12-31T00:00:00.000000']

# %%
print(t2)
# Out:
# ['1992-01-01' '1992-01-02' '1992-01-03' ... '2020-12-29' '2020-12-30'
#  '2020-12-31']

# %%
print(t3)
# Out:
# [['1992-01-01T00:00:00.000000000']
#  ['1992-01-02T00:00:00.000000000']
#  ['1992-01-03T00:00:00.000000000']
#  ...
#  ['2020-12-29T00:00:00.000000000']
#  ['2020-12-30T00:00:00.000000000']
#  ['2020-12-31T00:00:00.000000000']]

# %%
assert_equal({"t1": t1, "t2": t2, "t3": t3})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 assert_equal({"t1": t1, "t2": t2, "t3": t3})
#
# Cell In[11], line 17, in assert_equal(coord_dict)
#      15 a, b = names[i] ,names[j]
#      16 if not np.array_equal(coord_dict[a], coord_dict[b]):
# ---> 17     raise ValueError(f"ERROR: {a} and {b} not equal")
#
# ValueError: ERROR: t1 and t3 not equal

# %%
assert_equal({"lat1": lat1, "lat2": lat2, "lat3": lat3})

# %%
assert_equal({"lon1": lon1, "lon2": lon2, "lon3": lon3})

# %%
t3.shape
# Out:
# (10593, 1)

# %%
t1.shape
# Out:
# (10593,)

# %%
t3.astype('datetime64[D]')
# Out:
# array([['1992-01-01'],
#        ['1992-01-02'],
#        ['1992-01-03'],
#        ...,
#        ['2020-12-29'],
#        ['2020-12-30'],
#        ['2020-12-31']], dtype='datetime64[D]')
