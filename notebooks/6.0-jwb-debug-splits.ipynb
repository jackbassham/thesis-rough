# %%
import numpy as np

# %%
train = np.load('/data/globus/jbassham/thesis-rough/model_inputs/south/04082026_0901/train.npz')

# %%
print(train.keys)
# Out:
# <bound method Mapping.keys of NpzFile '/data/globus/jbassham/thesis-rough/model_inputs/south/04082026_0901/train.npz' with keys: y, x, ri_t0>

# %%
train['y'].shape
# Out:
# (9131, 2, 81, 522)

# %%
type(train['y'])
# Out:
# numpy.ndarray

# %%
train['x'].shape
# Out:
# (9131, 4, 81, 522)

# %%
train['x'].dtype
# Out:
# dtype('float64')

# %%
train['ri_t0'].shape
# Out:
# (9131, 1, 81, 522)

# %%
type(train['ri_t0'])
# Out:
# numpy.ndarray
