# %%
import numpy as np

# %%
train = np.load('/data/globus/jbassham/thesis-rough/model_inputs/south/04082026_0901/train.npz')

# %%
print(train.keys)

# %%
train['y'].shape

# %%
type(train['y'])

# %%
train['x'].shape

# %%
train['x'].dtype

# %%
train['ri_t0'].shape

# %%
type(train['ri_t0'])
