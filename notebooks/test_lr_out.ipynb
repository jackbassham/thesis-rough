# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA

# %%
 # Load in model predictions

data = np.load('/home/jbassham/jack/thesis-rough/data/model-output/lr-cf/nh/20260107_164301/preds_lr_cf_nh19922020_20260107_164301.npz')

upred = data['y_pred'][:,0,:,:]
vpred = data['y_pred'][:,1,:,:]

utrue = data['y_true'][:,0,:,:]
vtrue = data['y_true'][:,1,:,:]

# %%
plt.pcolormesh(upred[0,:,:])
plt.colorbar()
plt.show()

# %%
plt.pcolormesh(utrue[0,:,:])
plt.colorbar()
plt.show()

# %%
plt.pcolormesh((utrue[0,:,:] - upred[0,:,:]))
plt.colorbar()
plt.show()

# %%
plt.pcolormesh(vpred[0,:,:])
plt.colorbar()
plt.show()

# %%
plt.pcolormesh(vtrue[0,:,:])
plt.colorbar()
plt.show()

# %%
data = np.load('/home/jbassham/jack/thesis-rough/data/model-output/lr-cf/nh/20260107_164301/coef_fit_lr_cf_nh19922020_20260107_164301.npz')

ufit = data['fit_tr'][:,0,:,:]
vfit = data['fit_tr'][:,1,:,:]

utrue_tr = data['true_tr'][:,0,:,:]
vtrue_tr = data['true_tr'][:,1,:,:]

m = data['m']

# %%
plt.pcolormesh(ufit[0,:,:])
plt.colorbar()

# %%
plt.pcolormesh(utrue_tr[0,:,:])
plt.colorbar()

# %%
plt.pcolormesh(utrue_tr[0,:,:] - ufit[0,:,:])

# %%
for ms in m:
    plt.pcolormesh(ms)
    plt.colorbar()
    plt.show()

# %%
def lr_train(x_train, y_train):

    # TODO dynamic number of input channels and coefficients

    # Define number of input channels for gram matrix
    nin = 3 # complex wind (za), complex ice concentration (zci), complex constant 

    # Define number of complex coefficients
    nzm = 3 # A, B, C
   
    # Get dimensions for output arrays
    nt, _, nlat, nlon = np.shape(y_train)

    # Unpack target arrays
    ui_t0 = y_train[:,0,:,:]
    vi_t0 = y_train[:,1,:,:]

    # Unpack feature arrays
    ua_t0 = x_train[:,0,:,:]
    va_t0 = x_train[:,1,:,:]
    ci_t1 = x_train[:,2,:,:]

    # TODO fix nin for zm_all (just a coincidence that it matches with nin)
    # need A, B, C (za, ua, constant)

    # TODO switch order of gram matrix so constant is at end?
    # for consisitency with lr equation Ax + Bx + C

    # Initialize output arrays
    ztrue_all = np.full((nt, nlat, nlon), np.nan, dtype = complex) # true present day ice velocity vector, complex
    zfit_all = np.full((nt, nlat, nlon), np.nan, dtype = complex) # present day fit ice velocity, complex
    zm_all = np.full((nzm, nlat, nlon), np.nan, dtype = complex) # lr coefficients (A, B, C), complex
    
    # Iterate through each latitude, longitude gridpoint
    for ilat in range(nlat):
        for ilon in range(nlon):

            # Skip over land points
            if np.all(np.logical_or(np.isnan(ui_t0[:,ilat,ilon]), np.isnan(vi_t0[:,ilat,ilon]))):
                continue

            else:
                try:
                    # Handle missing data
                    
                    # Initialize mask for valid values
                    true_mask = np.ones_like(ui_t0[:,ilat,ilon], dtype=bool) # 1 = True = Inclusion

                    # Set 'True' for indices with nan values, 'False' for valid
                    inan = np.logical_or(np.isnan(ui_t0[:,ilat,ilon]), np.isnan(vi_t0[:,ilat,ilon]))

                    # Set NaN indices to False (Exclusion) (~ inverts 'True' where nan to 'False')
                    true_mask = ~inan

                    # Filter inputs to valid indices
                    ui_t0_filt = ui_t0[true_mask,ilat,ilon]
                    vi_t0_filt = vi_t0[true_mask,ilat,ilon]
                    ua_t0_filt = ua_t0[true_mask,ilat,ilon]
                    va_t0_filt = va_t0[true_mask,ilat,ilon]
                    ci_t1_filt = ci_t1[true_mask,ilat,ilon]

                    # Convert to complex
                    zi_t0 = ui_t0_filt + vi_t0_filt*1j # Complex 'today' ice velocity vector       
                    za_t0 = ua_t0_filt + va_t0_filt*1j # Complex 'today' wind vector
                    zci_t1 = ci_t1_filt + ci_t1_filt*1j # Complex 'yesterday' ice concentration
                    
                    # Store true complex ice velocity vectors at valid points
                    ztrue_all[true_mask, ilat, ilon] = zi_t0

                    # Define size of valid batch at current grid point
                    nt_ij = len(ui_t0_filt)

                    # Define gram matrix
                    G = np.ones(((nt_ij, nin)), dtype = complex) 

                    G[:,0] = za_t0 # Present day wind velocity, complex
                    G[:,1] = zci_t1 # Previous day ice concentration, complex
                    
                    # NOTE last column of G constant

                    # Define data matrix
                    d = zi_t0.T

                    # Solve for lr coefficients
                    zm = (LA.inv((G.conj().T @ G))) @ G.conj().T @ d

                    # Save lr coefficients
                    for izm in range(len(zm)):
                        zm_all[izm, ilat, ilon] = zm[izm]

                    # Calculate fit
                    zfit = G @ zm
                    
                    # Store predicted complex ice velocity vectors at valid points
                    zfit_all[true_mask, ilat, ilon] = zfit

                except Exception as e:
                    print(f"Error at lat={ilat}, lon={ilon}: {e}")

        print(f'lat {ilat} complete')
        
    return zm_all, zfit_all, ztrue_all

# %%
def lr_test(x_test, y_test, zm):

    # TODO dynamic number of input channels and coefficients

    # Define number of input channels for gram matrix
    nin = 3 # complex wind (za), complex ice concentration (zci), complex constant 
   
    # Get dimensions for output arrays
    nt, _, nlat, nlon = np.shape(y_test)

    # Unpack target arrays
    ui_t0 = y_test[:,0,:,:]
    vi_t0 = y_test[:,1,:,:]

    # Unpack feature arrays
    ua_t0 = x_test[:,0,:,:]
    va_t0 = x_test[:,1,:,:]
    ci_t1 = x_test[:,2,:,:]
      
    # Initialize output arrays
    ztrue_all = np.full((nt, nlat, nlon), np.nan, dtype = complex) # True complex 'today' ice velocity vectors
    zpred_all = np.full((nt, nlat, nlon), np.nan, dtype = complex) # Predicted complex 'today' ice velocity vectors
    
    # Iterate through each latitude, longitude gridpoint
    for ilat in range(nlat):
        for ilon in range(nlon):

            # Skip over land points
            if np.all(np.logical_or(np.isnan(ui_t0[:,ilat,ilon]), np.isnan(vi_t0[:,ilat,ilon]))):
                continue

            else:
                try:
                    # Handle missing data
                    
                    # Initialize mask for valid values
                    true_mask = np.ones_like(ui_t0[:,ilat,ilon], dtype=bool) # 1 = True = Inclusion

                    # Set 'True' for indices with nan values, 'False' for valid
                    inan = np.logical_or(np.isnan(ui_t0[:,ilat,ilon]), np.isnan(vi_t0[:,ilat,ilon]))

                    # Set NaN indices to False (Exclusion) (~ inverts 'True' where nan to 'False')
                    true_mask = ~inan

                    # Filter inputs to valid indices
                    ui_t0_filt = ui_t0[true_mask,ilat,ilon]
                    vi_t0_filt = vi_t0[true_mask,ilat,ilon]
                    ua_t0_filt = ua_t0[true_mask,ilat,ilon]
                    va_t0_filt = va_t0[true_mask,ilat,ilon]
                    ci_t1_filt = ci_t1[true_mask,ilat,ilon]

                    # Convert to complex
                    zi_t0 = ui_t0_filt + vi_t0_filt*1j # Complex 'today' ice velocity vector       
                    za_t0 = ua_t0_filt + va_t0_filt*1j # Complex 'today' wind vector
                    zci_t1 = ci_t1_filt + ci_t1_filt*1j # Complex 'yesterday' ice concentration
                    
                    # Store true complex ice velocity vectors at valid points
                    ztrue_all[true_mask, ilat, ilon] = zi_t0

                    # Define size of valid batch at current grid point
                    nt_ij = len(ui_t0_filt)

                    # Define gram matrix
                    G = np.ones(((nt_ij, nin)), dtype = complex) 

                    G[:,0] = za_t0 # Present day wind velocity, complex
                    G[:,1] = zci_t1 # Previous day ice concentration, complex
                    
                    # NOTE last column of G constant

                    # Define data matrix
                    d = zi_t0.T

                    # Get valid coefficients at grid point
                    zm_ij = zm[:,ilat,ilon]

                    # Calculate fit
                    zpred = G @ zm_ij
            
                    # Store predicted complex ice velocity vectors at valid points
                    zpred_all[true_mask, ilat, ilon] = zpred

                except Exception as e:
                    print(f"Error at lat={ilat}, lon={ilon}: {e}")

        print(f'ilat {ilat} complete')

    return zpred_all, ztrue_all

# %%
# Load in training data
data = np.load('/home/jbassham/jack/thesis-rough/data/lr-input/nh/20260107_164301/train_nh19922020_20260107_164301.npz')
x_train = data['x_train']
y_train = data['y_train']

# Load in testing data
data = np.load('/home/jbassham/jack/thesis-rough/data/lr-input/nh/20260107_164301/test_nh19922020_20260107_164301.npz')
x_test = data['x_test']
y_test = data['y_test']

# %%
# Get train batch dimensions
nt_tr, nout, nlat, nlon = np.shape(y_train)

# Get input channel dimensions
_, nin, _, _, = np.shape(x_train)

# TODO make coefficient dimension dynamic

# Get coefficient dimension
nm = nin + 1 # NOTE +1 for u and v complex concentration projections 
nm = nm + 2 # NOTE +2 for u and v constants (mean ~ 0) (constant column G[0])

# Get test batch dimensions
nt_te, _, _, _ = np.shape(y_test)

# Train model
zm, zfit_tr, ztrue_tr = lr_train(x_train, y_train)

# Initialize arrays for real training outputs
# NOTE two extra coefficients for u and v mean
m = np.full((nm, nlat, nlon), np.nan) # model coefficients, real
fit_tr = np.full((nt_tr, nout, nlat, nlon), np.nan) # training fit, real
true_tr = np.full((nt_tr, nout, nlat, nlon), np.nan) # training true, real

# TODO make loop or use advanced indexing for real and imaginary coefficients

# Convert training coefficients to real
m[0, :, :] = zm[0, :, :].real # C_uproj, (constant)
m[1, :, :] = zm[0, :, :].imag # C_vproj, (constant)
m[2, :, :] = zm[1, :, :].real # A_uproj, (ua_t0)
m[3, :, :] = zm[1, :, :].imag # A_uproj, (va_t0)
m[4, :, :] = zm[2, :, :].real # B_uproj, (ci_t1)
m[5, :, :] = zm[2, :, :].imag # B_uproj, (ci_t1)

# Convert training fit to real
fit_tr[:, 0, :, :] = zfit_tr.real # ui_t0, fit
fit_tr[:, 1, :, :] = zfit_tr.imag # vi_t0, fit

# Convert training true to real
true_tr[:, 0, :, :] = ztrue_tr.real # ui_t0, true
true_tr[:, 1, :, :] = ztrue_tr.imag # vi_t0, true

# # Save coeffients, fit
# np.savez(
#     os.path.join(PATH_DEST, f"coef_fit_{MODEL_STR}_{FSTR_END_OUT}.npz"),
#     m = m,
#     fit_tr = fit_tr,
#     true_tr = true_tr,
# )
# Out:
# Error at lat=0, lon=163: Singular matrix
# Error at lat=0, lon=165: Singular matrix
# Error at lat=0, lon=167: Singular matrix
# Error at lat=0, lon=168: Singular matrix
# lat 0 complete
# Error at lat=1, lon=164: Singular matrix
# Error at lat=1, lon=167: Singular matrix
# Error at lat=1, lon=207: Singular matrix
# lat 1 complete
# Error at lat=2, lon=168: Singular matrix
# Error at lat=2, lon=169: Singular matrix
# Error at lat=2, lon=170: Singular matrix
# Error at lat=2, lon=207: Singular matrix
# Error at lat=2, lon=208: Singular matrix
# lat 2 complete
# Error at lat=3, lon=163: Singular matrix
# Error at lat=3, lon=164: Singular matrix
# lat 3 complete
# Error at lat=4, lon=170: Singular matrix
# Error at lat=4, lon=208: Singular matrix
# lat 4 complete
# Error at lat=5, lon=164: Singular matrix
# Error at lat=5, lon=165: Singular matrix
# Error at lat=5, lon=169: Singular matrix
# Error at lat=5, lon=172: Singular matrix
# Error at lat=5, lon=207: Singular matrix
# Error at lat=5, lon=208: Singular matrix
# Error at lat=5, lon=209: Singular matrix
# lat 5 complete
# Error at lat=6, lon=162: Singular matrix
# Error at lat=6, lon=165: Singular matrix
# Error at lat=6, lon=166: Singular matrix
# Error at lat=6, lon=208: Singular matrix
# Error at lat=6, lon=209: Singular matrix
# lat 6 complete
# Error at lat=7, lon=170: Singular matrix
# lat 7 complete
# Error at lat=8, lon=170: Singular matrix
# Error at lat=8, lon=208: Singular matrix
# Error at lat=8, lon=211: Singular matrix
# lat 8 complete
# Error at lat=9, lon=163: Singular matrix
# Error at lat=9, lon=207: Singular matrix
# Error at lat=9, lon=210: Singular matrix
# lat 9 complete
# Error at lat=10, lon=163: Singular matrix
# Error at lat=10, lon=164: Singular matrix
# Error at lat=10, lon=169: Singular matrix
# Error at lat=10, lon=174: Singular matrix
# Error at lat=10, lon=201: Singular matrix
# Error at lat=10, lon=208: Singular matrix
# Error at lat=10, lon=209: Singular matrix
# lat 10 complete
# Error at lat=11, lon=164: Singular matrix
# Error at lat=11, lon=201: Singular matrix
# Error at lat=11, lon=205: Singular matrix
# lat 11 complete
# Error at lat=12, lon=204: Singular matrix
# lat 12 complete
# Error at lat=13, lon=168: Singular matrix
# Error at lat=13, lon=200: Singular matrix
# Error at lat=13, lon=209: Singular matrix
# lat 13 complete
# Error at lat=14, lon=167: Singular matrix
# Error at lat=14, lon=168: Singular matrix
# Error at lat=14, lon=178: Singular matrix
# Error at lat=14, lon=189: Singular matrix
# Error at lat=14, lon=207: Singular matrix
# lat 14 complete
# Error at lat=15, lon=166: Singular matrix
# Error at lat=15, lon=168: Singular matrix
# Error at lat=15, lon=170: Singular matrix
# Error at lat=15, lon=194: Singular matrix
# lat 15 complete
# Error at lat=16, lon=166: Singular matrix
# Error at lat=16, lon=168: Singular matrix
# Error at lat=16, lon=178: Singular matrix
# Error at lat=16, lon=193: Singular matrix
# Error at lat=16, lon=204: Singular matrix
# Error at lat=16, lon=212: Singular matrix
# lat 16 complete
# Error at lat=17, lon=175: Singular matrix
# lat 17 complete
# Error at lat=18, lon=171: Singular matrix
# Error at lat=18, lon=173: Singular matrix
# Error at lat=18, lon=192: Singular matrix
# Error at lat=18, lon=193: Singular matrix
# Error at lat=18, lon=201: Singular matrix
# Error at lat=18, lon=204: Singular matrix
# Error at lat=18, lon=205: Singular matrix
# lat 18 complete
# Error at lat=19, lon=170: Singular matrix
# Error at lat=19, lon=178: Singular matrix
# Error at lat=19, lon=198: Singular matrix
# Error at lat=19, lon=200: Singular matrix
# Error at lat=19, lon=202: Singular matrix
# Error at lat=19, lon=203: Singular matrix
# Error at lat=19, lon=204: Singular matrix
# Error at lat=19, lon=205: Singular matrix
# Error at lat=19, lon=206: Singular matrix
# lat 19 complete
# Error at lat=20, lon=174: Singular matrix
# Error at lat=20, lon=202: Singular matrix
# Error at lat=20, lon=203: Singular matrix
# Error at lat=20, lon=204: Singular matrix
# Error at lat=20, lon=205: Singular matrix
# Error at lat=20, lon=206: Singular matrix
# Error at lat=20, lon=207: Singular matrix
# Error at lat=20, lon=214: Singular matrix
# Error at lat=20, lon=215: Singular matrix
# lat 20 complete
# Error at lat=21, lon=193: Singular matrix
# Error at lat=21, lon=194: Singular matrix
# Error at lat=21, lon=198: Singular matrix
# Error at lat=21, lon=202: Singular matrix
# Error at lat=21, lon=203: Singular matrix
# Error at lat=21, lon=204: Singular matrix
# Error at lat=21, lon=206: Singular matrix
# Error at lat=21, lon=207: Singular matrix
# Error at lat=21, lon=217: Singular matrix
# Error at lat=21, lon=218: Singular matrix
# lat 21 complete
# Error at lat=22, lon=201: Singular matrix
# Error at lat=22, lon=203: Singular matrix
# Error at lat=22, lon=204: Singular matrix
# Error at lat=22, lon=205: Singular matrix
# Error at lat=22, lon=206: Singular matrix
# Error at lat=22, lon=207: Singular matrix
# Error at lat=22, lon=211: Singular matrix
# Error at lat=22, lon=216: Singular matrix
# Error at lat=22, lon=217: Singular matrix
# lat 22 complete
# Error at lat=23, lon=205: Singular matrix
# Error at lat=23, lon=206: Singular matrix
# Error at lat=23, lon=207: Singular matrix
# Error at lat=23, lon=208: Singular matrix
# Error at lat=23, lon=209: Singular matrix
# Error at lat=23, lon=211: Singular matrix
# lat 23 complete
# Error at lat=24, lon=207: Singular matrix
# Error at lat=24, lon=213: Singular matrix
# Error at lat=24, lon=217: Singular matrix
# lat 24 complete
# Error at lat=25, lon=194: Singular matrix
# Error at lat=25, lon=197: Singular matrix
# Error at lat=25, lon=217: Singular matrix
# lat 25 complete
# Error at lat=26, lon=194: Singular matrix
# Error at lat=26, lon=202: Singular matrix
# Error at lat=26, lon=203: Singular matrix
# Error at lat=26, lon=217: Singular matrix
# lat 26 complete
# Error at lat=27, lon=195: Singular matrix
# Error at lat=27, lon=200: Singular matrix
# Error at lat=27, lon=202: Singular matrix
# Error at lat=27, lon=203: Singular matrix
# Error at lat=27, lon=219: Singular matrix
# lat 27 complete
# Error at lat=28, lon=207: Singular matrix
# Error at lat=28, lon=219: Singular matrix
# lat 28 complete
# Error at lat=29, lon=195: Singular matrix
# Error at lat=29, lon=207: Singular matrix
# Error at lat=29, lon=219: Singular matrix
# lat 29 complete
# Error at lat=30, lon=191: Singular matrix
# Error at lat=30, lon=195: Singular matrix
# Error at lat=30, lon=218: Singular matrix
# lat 30 complete
# Error at lat=31, lon=207: Singular matrix
# Error at lat=31, lon=215: Singular matrix
# lat 31 complete
# lat 32 complete
# Error at lat=33, lon=196: Singular matrix
# lat 33 complete
# Error at lat=34, lon=211: Singular matrix
# lat 34 complete
# Error at lat=35, lon=204: Singular matrix
# Error at lat=35, lon=215: Singular matrix
# lat 35 complete
# Error at lat=36, lon=193: Singular matrix
# Error at lat=36, lon=202: Singular matrix
# Error at lat=36, lon=209: Singular matrix
# Error at lat=36, lon=219: Singular matrix
# lat 36 complete
# Error at lat=37, lon=198: Singular matrix
# Error at lat=37, lon=207: Singular matrix
# Error at lat=37, lon=218: Singular matrix
# lat 37 complete
# Error at lat=38, lon=195: Singular matrix
# lat 38 complete
# Error at lat=39, lon=192: Singular matrix
# Error at lat=39, lon=199: Singular matrix
# lat 39 complete
# Error at lat=40, lon=196: Singular matrix
# Error at lat=40, lon=198: Singular matrix
# Error at lat=40, lon=207: Singular matrix
# Error at lat=40, lon=208: Singular matrix
# Error at lat=40, lon=210: Singular matrix
# Error at lat=40, lon=215: Singular matrix
# lat 40 complete
# Error at lat=41, lon=198: Singular matrix
# Error at lat=41, lon=207: Singular matrix
# Error at lat=41, lon=208: Singular matrix
# Error at lat=41, lon=209: Singular matrix
# Error at lat=41, lon=210: Singular matrix
# Error at lat=41, lon=214: Singular matrix
# lat 41 complete
# Error at lat=42, lon=209: Singular matrix
# Error at lat=42, lon=210: Singular matrix
# Error at lat=42, lon=214: Singular matrix
# Error at lat=42, lon=219: Singular matrix
# lat 42 complete
# Error at lat=43, lon=194: Singular matrix
# Error at lat=43, lon=209: Singular matrix
# Error at lat=43, lon=210: Singular matrix
# Error at lat=43, lon=214: Singular matrix
# Error at lat=43, lon=218: Singular matrix
# Error at lat=43, lon=219: Singular matrix
# Error at lat=43, lon=223: Singular matrix
# Error at lat=43, lon=251: Singular matrix
# lat 43 complete
# Error at lat=44, lon=200: Singular matrix
# Error at lat=44, lon=209: Singular matrix
# Error at lat=44, lon=211: Singular matrix
# Error at lat=44, lon=218: Singular matrix
# lat 44 complete
# Error at lat=45, lon=202: Singular matrix
# Error at lat=45, lon=209: Singular matrix
# Error at lat=45, lon=216: Singular matrix
# Error at lat=45, lon=217: Singular matrix
# Error at lat=45, lon=218: Singular matrix
# Error at lat=45, lon=222: Singular matrix
# Error at lat=45, lon=223: Singular matrix
# lat 45 complete
# Error at lat=46, lon=202: Singular matrix
# Error at lat=46, lon=204: Singular matrix
# Error at lat=46, lon=207: Singular matrix
# Error at lat=46, lon=216: Singular matrix
# Error at lat=46, lon=222: Singular matrix
# Error at lat=46, lon=223: Singular matrix
# Error at lat=46, lon=246: Singular matrix
# Error at lat=46, lon=250: Singular matrix
# lat 46 complete
# Error at lat=47, lon=203: Singular matrix
# Error at lat=47, lon=207: Singular matrix
# Error at lat=47, lon=209: Singular matrix
# Error at lat=47, lon=216: Singular matrix
# Error at lat=47, lon=223: Singular matrix
# Error at lat=47, lon=246: Singular matrix
# lat 47 complete
# Error at lat=48, lon=205: Singular matrix
# Error at lat=48, lon=206: Singular matrix
# Error at lat=48, lon=209: Singular matrix
# Error at lat=48, lon=211: Singular matrix
# Error at lat=48, lon=221: Singular matrix
# Error at lat=48, lon=223: Singular matrix
# Error at lat=48, lon=226: Singular matrix
# lat 48 complete
# Error at lat=49, lon=205: Singular matrix
# Error at lat=49, lon=219: Singular matrix
# Error at lat=49, lon=231: Singular matrix
# Error at lat=49, lon=243: Singular matrix
# lat 49 complete
# Error at lat=50, lon=213: Singular matrix
# Error at lat=50, lon=215: Singular matrix
# Error at lat=50, lon=219: Singular matrix
# Error at lat=50, lon=227: Singular matrix
# Error at lat=50, lon=231: Singular matrix
# Error at lat=50, lon=243: Singular matrix
# lat 50 complete
# Error at lat=51, lon=208: Singular matrix
# Error at lat=51, lon=221: Singular matrix
# Error at lat=51, lon=227: Singular matrix
# Error at lat=51, lon=248: Singular matrix
# lat 51 complete
# Error at lat=52, lon=221: Singular matrix
# Error at lat=52, lon=234: Singular matrix
# Error at lat=52, lon=238: Singular matrix
# Error at lat=52, lon=242: Singular matrix
# Error at lat=52, lon=252: Singular matrix
# lat 52 complete
# Error at lat=53, lon=218: Singular matrix
# Error at lat=53, lon=220: Singular matrix
# Error at lat=53, lon=235: Singular matrix
# Error at lat=53, lon=236: Singular matrix
# Error at lat=53, lon=237: Singular matrix
# Error at lat=53, lon=242: Singular matrix
# Error at lat=53, lon=243: Singular matrix
# lat 53 complete
# Error at lat=54, lon=212: Singular matrix
# Error at lat=54, lon=219: Singular matrix
# Error at lat=54, lon=220: Singular matrix
# Error at lat=54, lon=227: Singular matrix
# Error at lat=54, lon=229: Singular matrix
# Error at lat=54, lon=230: Singular matrix
# Error at lat=54, lon=235: Singular matrix
# Error at lat=54, lon=237: Singular matrix
# lat 54 complete
# Error at lat=55, lon=214: Singular matrix
# Error at lat=55, lon=217: Singular matrix
# Error at lat=55, lon=221: Singular matrix
# Error at lat=55, lon=222: Singular matrix
# Error at lat=55, lon=229: Singular matrix
# lat 55 complete
# Error at lat=56, lon=214: Singular matrix
# Error at lat=56, lon=215: Singular matrix
# Error at lat=56, lon=216: Singular matrix
# Error at lat=56, lon=221: Singular matrix
# Error at lat=56, lon=223: Singular matrix
# Error at lat=56, lon=246: Singular matrix
# lat 56 complete
# Error at lat=57, lon=215: Singular matrix
# Error at lat=57, lon=216: Singular matrix
# Error at lat=57, lon=217: Singular matrix
# Error at lat=57, lon=224: Singular matrix
# Error at lat=57, lon=226: Singular matrix
# lat 57 complete
# Error at lat=58, lon=224: Singular matrix
# Error at lat=58, lon=227: Singular matrix
# Error at lat=58, lon=232: Singular matrix
# Error at lat=58, lon=237: Singular matrix
# Error at lat=58, lon=245: Singular matrix
# lat 58 complete
# Error at lat=59, lon=216: Singular matrix
# Error at lat=59, lon=222: Singular matrix
# Error at lat=59, lon=225: Singular matrix
# Error at lat=59, lon=237: Singular matrix
# Error at lat=59, lon=243: Singular matrix
# lat 59 complete
# Error at lat=60, lon=216: Singular matrix
# lat 60 complete
# Error at lat=61, lon=217: Singular matrix
# lat 61 complete
# Error at lat=62, lon=217: Singular matrix
# Error at lat=62, lon=218: Singular matrix
# Error at lat=62, lon=220: Singular matrix
# Error at lat=62, lon=235: Singular matrix
# Error at lat=62, lon=236: Singular matrix
# lat 62 complete
# Error at lat=63, lon=216: Singular matrix
# Error at lat=63, lon=217: Singular matrix
# Error at lat=63, lon=235: Singular matrix
# Error at lat=63, lon=236: Singular matrix
# lat 63 complete
# Error at lat=64, lon=217: Singular matrix
# Error at lat=64, lon=241: Singular matrix
# lat 64 complete
# Error at lat=65, lon=217: Singular matrix
# Error at lat=65, lon=218: Singular matrix
# lat 65 complete
# Error at lat=66, lon=217: Singular matrix
# Error at lat=66, lon=218: Singular matrix
# Error at lat=66, lon=221: Singular matrix
# lat 66 complete
# Error at lat=67, lon=217: Singular matrix
# Error at lat=67, lon=219: Singular matrix
# Error at lat=67, lon=221: Singular matrix
# lat 67 complete
# Error at lat=68, lon=217: Singular matrix
# Error at lat=68, lon=219: Singular matrix
# lat 68 complete
# Error at lat=69, lon=217: Singular matrix
# lat 69 complete
# Error at lat=70, lon=214: Singular matrix
# lat 70 complete
# Error at lat=71, lon=214: Singular matrix
# lat 71 complete
# Error at lat=72, lon=208: Singular matrix
# Error at lat=72, lon=213: Singular matrix
# lat 72 complete
# Error at lat=73, lon=209: Singular matrix
# Error at lat=73, lon=212: Singular matrix
# Error at lat=73, lon=214: Singular matrix
# Error at lat=73, lon=216: Singular matrix
# Error at lat=73, lon=217: Singular matrix
# lat 73 complete
# Error at lat=74, lon=209: Singular matrix
# Error at lat=74, lon=215: Singular matrix
# Error at lat=74, lon=217: Singular matrix
# lat 74 complete
# lat 75 complete
# lat 76 complete
# lat 77 complete
# lat 78 complete
# Error at lat=79, lon=214: Singular matrix
# lat 79 complete
# lat 80 complete
# lat 81 complete
# lat 82 complete
# lat 83 complete
# lat 84 complete
# lat 85 complete
# lat 86 complete
# lat 87 complete
# lat 88 complete
# lat 89 complete
# lat 90 complete
# lat 91 complete
# lat 92 complete
# lat 93 complete
# lat 94 complete
# lat 95 complete
# lat 96 complete
# lat 97 complete
# lat 98 complete
# lat 99 complete
# lat 100 complete
# lat 101 complete
# lat 102 complete
# lat 103 complete
# lat 104 complete
# lat 105 complete
# lat 106 complete
# lat 107 complete
# lat 108 complete
# lat 109 complete
# lat 110 complete
# lat 111 complete
# lat 112 complete
# lat 113 complete
# lat 114 complete
# lat 115 complete
# lat 116 complete
# lat 117 complete
# lat 118 complete
# lat 119 complete
# lat 120 complete
# lat 121 complete
# lat 122 complete
# lat 123 complete
# lat 124 complete
# lat 125 complete
# lat 126 complete
# lat 127 complete
# lat 128 complete
# lat 129 complete
# lat 130 complete
# lat 131 complete
# lat 132 complete
# lat 133 complete
# lat 134 complete

# %%
# Get predictions on test set
zpred_te, ztrue_te = lr_test(x_test, y_test, zm)

# Intialize arrays for test output predictions
# NOTE y notation used for consistency with CNN and plotting
y_pred = np.full((nt_te, nout, nlat, nlon), np.nan) 
y_true = np.full((nt_te, nout, nlat, nlon), np.nan)

# Convert test predictions to real
y_pred[:,0,:,:] = zpred_te.real # ui_t0, pred
y_pred[:,1,:,:] = zpred_te.imag # vi_t0, pred

# Convert test true to real
y_true[:,0,:,:] = ztrue_te.real # ui_t0, true
y_true[:,1,:,:] = ztrue_te.imag # vi_t0, true

# # Save predictions
# np.savez(
#     os.path.join(PATH_DEST, f"preds_{MODEL_STR}_{FSTR_END_OUT}.npz"),
#     y_pred = y_pred,
#     y_true = y_true,
# )
# Out:
# ilat 0 complete
# ilat 1 complete
# ilat 2 complete
# ilat 3 complete
# ilat 4 complete
# ilat 5 complete
# ilat 6 complete
# ilat 7 complete
# ilat 8 complete
# ilat 9 complete
# ilat 10 complete
# ilat 11 complete
# ilat 12 complete
# ilat 13 complete
# ilat 14 complete
# ilat 15 complete
# ilat 16 complete
# ilat 17 complete
# ilat 18 complete
# ilat 19 complete
# ilat 20 complete
# ilat 21 complete
# ilat 22 complete
# ilat 23 complete
# ilat 24 complete
# ilat 25 complete
# ilat 26 complete
# ilat 27 complete
# ilat 28 complete
# ilat 29 complete
# ilat 30 complete
# ilat 31 complete
# ilat 32 complete
# ilat 33 complete
# ilat 34 complete
# ilat 35 complete
# ilat 36 complete
# ilat 37 complete
# ilat 38 complete
# ilat 39 complete
# ilat 40 complete
# ilat 41 complete
# ilat 42 complete
# ilat 43 complete
# ilat 44 complete
# ilat 45 complete
# ilat 46 complete
# ilat 47 complete
# ilat 48 complete
# ilat 49 complete
# ilat 50 complete
# ilat 51 complete
# ilat 52 complete
# ilat 53 complete
# ilat 54 complete
# ilat 55 complete
# ilat 56 complete
# ilat 57 complete
# ilat 58 complete
# ilat 59 complete
# ilat 60 complete
# ilat 61 complete
# ilat 62 complete
# ilat 63 complete
# ilat 64 complete
# ilat 65 complete
# ilat 66 complete
# ilat 67 complete
# ilat 68 complete
# ilat 69 complete
# ilat 70 complete
# ilat 71 complete
# ilat 72 complete
# ilat 73 complete
# ilat 74 complete
# ilat 75 complete
# ilat 76 complete
# ilat 77 complete
# ilat 78 complete
# ilat 79 complete
# ilat 80 complete
# ilat 81 complete
# ilat 82 complete
# ilat 83 complete
# ilat 84 complete
# ilat 85 complete
# ilat 86 complete
# ilat 87 complete
# ilat 88 complete
# ilat 89 complete
# ilat 90 complete
# ilat 91 complete
# ilat 92 complete
# ilat 93 complete
# ilat 94 complete
# ilat 95 complete
# ilat 96 complete
# ilat 97 complete
# ilat 98 complete
# ilat 99 complete
# ilat 100 complete
# ilat 101 complete
# ilat 102 complete
# ilat 103 complete
# ilat 104 complete
# ilat 105 complete
# ilat 106 complete
# ilat 107 complete
# ilat 108 complete
# ilat 109 complete
# ilat 110 complete
# ilat 111 complete
# ilat 112 complete
# ilat 113 complete
# ilat 114 complete
# ilat 115 complete
# ilat 116 complete
# ilat 117 complete
# ilat 118 complete
# ilat 119 complete
# ilat 120 complete
# ilat 121 complete
# ilat 122 complete
# ilat 123 complete
# ilat 124 complete
# ilat 125 complete
# ilat 126 complete
# ilat 127 complete
# ilat 128 complete
# ilat 129 complete
# ilat 130 complete
# ilat 131 complete
# ilat 132 complete
# ilat 133 complete
# ilat 134 complete

# %%
upred = y_pred[:,0,:,:]
vpred = y_pred[:,1,:,:]

utrue = y_true[:,0,:,:]
vtrue = y_true[:,1,:,:]

# %%
plt.pcolormesh(upred[0,:,:])
plt.colorbar()
plt.show()

# %%
plt.pcolormesh(utrue[0,:,:])
plt.colorbar()
plt.show()
