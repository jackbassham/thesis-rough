# %%
import numpy as np
import os
import torch

# %%
import matplotlib.pyplot as plt

# %%
# Load old V6 train input variable file
fnam = '/home/jbassham/jack/old-thesis/data/sh/inputs_v6/cnn_inputs/train_sh_1992_2020.pt'

# Unpack input variables from .npz file
x_trainv6, y_trainv6, _ = torch.load(fnam)

x_trainv6 = x_trainv6.numpy()
y_trainv6 = y_trainv6.numpy()

x_trainv6[x_trainv6 == 0] = np.nan
y_trainv6[y_trainv6 == 0] = np.nan

print(np.shape(x_trainv6))
print(np.shape(y_trainv6))

uit_trv6 = y_trainv6[:,0,:,:]
vit_trv6 = y_trainv6[:,1,:,:]


uwt_trv6 = x_trainv6[:,0,:,:]
vwt_trv6 = x_trainv6[:,1,:,:]
icy_trv6 = x_trainv6[:,2,:,:]

# Pack input variables into list
invars_trainv6 = [uit_trv6, vit_trv6, uwt_trv6, vwt_trv6, icy_trv6]

# %%
for invar in invars_trainv6:
        plt.figure(figsize = (12,3))
        plt.pcolormesh(invar[0,:,:])
        plt.colorbar()
        plt.show()

# %%
# Load in new LR train input variable file
fnam = '/home/jbassham/jack/thesis-rough/data/lr-input/sh/20260107_164301/train_sh19922020_20260107_164301.npz'

data = np.load(fnam)

# Unpack input variables from .npz file
x_train = data['x_train']
y_train = data['y_train']

# x_train[x_train == 0] = np.nan
# y_train[y_train == 0] = np.nan

print(np.shape(x_train))
print(np.shape(y_train))

uit_tr = y_train[:,0,:,:]
vit_tr = y_train[:,1,:,:]

uwt_tr = x_train[:,0,:,:]
vwt_tr = x_train[:,1,:,:]
icy_tr = x_train[:,2,:,:]

# Pack input variables into list
invars_train = [uit_tr, vit_tr, uwt_tr, vwt_tr, icy_tr]

# %%
for invar in invars_train:
        plt.figure(figsize = (12,3))
        plt.pcolormesh(invar[0,:,:])
        plt.colorbar()
        plt.show()

# %%
del_invars = [a - b for a, b in zip(invars_train, invars_trainv6)]

# %%
for invar in del_invars:
        plt.figure(figsize = (12,3))
        plt.pcolormesh(invar[180,:,:])
        plt.colorbar()
        plt.show()

# %%
# Load old LR train input variable file
fnam = '/home/jbassham/jack/old-thesis/data/sh/inputs_v6/inputs_normalized_sh_1992_2020.npz'
data = np.load(fnam)

# Unpack input variables from .npz file
uit_tr = data['uitn'][:9131,:,:]
vit_tr = data['vitn'][:9131,:,:]

print(np.shape(uit_tr))

uwt_tr = data['uwtn'][:9131,:,:]
vwt_tr = data['vwtn'][:9131,:,:]
icy_tr = data['icyn'][:9131,:,:]

print(np.shape(uwt_tr))

# Pack input variables into list
invars_train_lr6 = [uit_tr, vit_tr, uwt_tr, vwt_tr, icy_tr]

# %%
del_invars = [a - b for a, b in zip(invars_train, invars_train_lr6)]

# %%
for invar in del_invars:
        plt.figure(figsize = (12,3))
        plt.pcolormesh(invar[180,:,:])
        plt.colorbar()
        plt.show()

# %%
# Load new cnn train input variable file
fnam = 'data/cnn-input/sh/20260107_164301/train_sh19922020_20260107_164301.pt'

# Unpack input variables from .npz file
x_train, y_train, _ = torch.load(fnam)

x_train = x_train.numpy()
y_train = y_train.numpy()

x_train[x_train == 0] = np.nan
y_train[y_train == 0] = np.nan

print(np.shape(x_train))
print(np.shape(y_train))

uit_tr = y_train[:,0,:,:]
vit_tr = y_train[:,1,:,:]


uwt_tr = x_train[:,0,:,:]
vwt_tr = x_train[:,1,:,:]
icy_tr = x_train[:,2,:,:]

# Pack input variables into list
invars_train_newcnn = [uit_tr, vit_tr, uwt_tr, vwt_tr, icy_tr]

# %%
del_invars = [a - b for a, b in zip(invars_train_newcnn, invars_trainv6)]

# %%
for invar in del_invars:
        plt.figure(figsize = (12,3))
        plt.pcolormesh(invar[180,:,:])
        plt.colorbar()
        plt.show()

# %%
# Load recent but not newest cnn train input variable file
# Possible concnetration data version discrepancy
fnam = '/home/jbassham/jack/thesis-rough/data/cnn-input/sh/train_sh_1992_2020.pt'

# Unpack input variables from .npz file
x_train, y_train, _ = torch.load(fnam)

x_train = x_train.numpy()
y_train = y_train.numpy()

x_train[x_train == 0] = np.nan
y_train[y_train == 0] = np.nan

print(np.shape(x_train))
print(np.shape(y_train))

uit_tr = y_train[:,0,:,:]
vit_tr = y_train[:,1,:,:]


uwt_tr = x_train[:,0,:,:]
vwt_tr = x_train[:,1,:,:]
icy_tr = x_train[:,2,:,:]

# Pack input variables into list
invars_train_midcnn = [uit_tr, vit_tr, uwt_tr, vwt_tr, icy_tr]

# %%
del_invars = [a - b for a, b in zip(invars_train_newcnn, invars_train_midcnn)]

# %%
for invar in del_invars:
        plt.figure(figsize = (12,3))
        plt.pcolormesh(invar[180,:,:])
        plt.colorbar()
        plt.show()
