# %%
import numpy as np

# %%
# Load in training data
data = np.load('/home/jbassham/jack/thesis-rough/data/mask-norm/sh/inputs_normalized_sh_1992_2020.npz')

print(data.files)

# %%
# Convert to complex
zi= ui + vi*1j # Complex 'today' ice velocity vector       
za = ua + va*1j # Complex 'today' wind vector
zci = ci + ci*1j # Complex 'yesterday' ice concentration
