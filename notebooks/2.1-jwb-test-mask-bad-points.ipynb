# %%
import cartopy.crs as ccrs
import cmocean as cmo
import matplotlib.pyplot as plt
import numpy as np

# %%
HEM = 'sh'

# %%
fnam = '/home/jbassham/jack/thesis-rough/data/lr-input/sh/01162026_1647/test_sh19922020_01162026_1647.npz'

data = np.load(fnam)
y_test = data['y_test']

u_true = y_test[:,0,:,:]
v_true = y_test[:,1,:,:]

ri_t0 = data['r_test']

x_test = data['x_test']

ua_t0 = x_test[:,0,:,:]
ua_t0 = x_test[:,1,:,:]
ci_t1 = x_test[:,2,:,:]

# %%
nt, nlat, nlon = np.shape(u_true)
print(np.shape(u_true))

# %%
fnam = '/home/jbassham/jack/thesis-rough/data/regrid/sh/01072026_1643/motion_ppv4_latlon_sh19922020_01072026_1643.npz'

data = np.load(fnam)

# Import the last 731 days of r_raw (match test indices)
r_raw = data['r'][-731:,:,:]

np.shape(r_raw)

# %%
fnam = '/home/jbassham/jack/thesis-rough/data/regrid/sh/01072026_1643/con_nimbus7_latlon_sh19922020_01072026_1643.npz'

data = np.load(fnam)

# Import the last 731 days of raw concentration (match test indices, present day)
ci_raw_t0 = data['ci'][-731:,:,:]

# %%
fnam = '/home/jbassham/jack/thesis-rough/data/coordinates/sh/01072026_1643/coord_sh19922020_01072026_1643.npz'

data = np.load(fnam)
lat = data['lat']
lon = data['lon']

# %%
def vartrue(true):

    truebar = np.nanmean(true, axis = 0)

    vartrue = np.nanmean((true - truebar) ** 2, axis = 0)

    return vartrue

# %%
vartrue_u = vartrue(u_true)
vartrue_v = vartrue(v_true)

# %%
def plot_metric(u_data, v_data, lon, lat, metric):

    # Set longitude bounds for plot (full zonal coverage)
    lon_min = -180
    lon_max = 180

    # Set latitude bounds based on hemisphere
    if HEM == 'sh':
        lat_min = -90
        lat_max = -65
    elif HEM =='nh':
        lat_min = 65
        lat_max = 90

    # Define plot proection based on hempisphere
    if HEM == 'sh':
        projection = ccrs.SouthPolarStereo()
    elif HEM == 'nh':
        projection = ccrs.NorthPolarStereo()

    # Define data-to-plot's coordinate reference system
    # NOTE, used for 'crs' and 'transform' cartopy parameters
    crs = ccrs.PlateCarree()

    # Set color map
    cmap = cmo.cm.matter_r  # red blue colormap from cmocean

    # Saturate colormap to show small values
    vmin = 0
    vmax = 0.05
    
    # Initialize subplots
    fig, axs = plt.subplots(
        nrows = 1,
        ncols = 2,
        figsize = (6,3),
        subplot_kw = {'projection': projection},
        constrained_layout = True
    )

    # Plot left plot; zonal evaluation
    axs[0].set_extent([lon_min, lon_max, lat_min, lat_max], crs = crs)
    axs[0].coastlines
    # Plot pcolormesh plot
    pcm_0 = axs[0].pcolormesh(
        lon, lat, u_data,
        transform = crs,
        cmap = cmap, 
        vmin = vmin, vmax = vmax
    )
    axs[0].set_title("zonal")
    # Add colorbar
    plt.colorbar(pcm_0, ax = axs[0], orientation = 'vertical')

    # Plot right plot; meridional evaluation
    axs[1].set_extent([lon_min, lon_max, lat_min, lat_max], crs = crs)
    axs[1].coastlines
    # Plot pcolormesh plot
    pcm_1 = axs[1].pcolormesh(
        lon, lat, v_data,
        transform = crs,
        cmap = cmap, 
        vmin = vmin, vmax = vmax
    )
    axs[1].set_title("meridional")
    # Add colorbar
    plt.colorbar(pcm_1, ax = axs[1], orientation = 'vertical')

    # Add title to plot
    fig.suptitle(f"{metric}", fontweight = 'bold')

    # Format with tight layout
    fig.tight_layout

    # Add text with means
    fig.text(0, -0.05, f"mean zonal {metric}: {np.nanmean(u_data):.4f}")
    fig.text(0.5, -0.05, f"mean meridional {metric}: {np.nanmean(v_data):.4f}")

    # # Define filemane for figure
    # fnam = f"{metric}_{MODEL_STR}_{TIMESTAMP_MODEL}.png"

    # # Save figure
    # plt.savefig(os.path.join(PATH_DEST, fnam), bbox_inches = 'tight')

    return

# %%
def plot_metric2(u_data, v_data, lon, lat, metric):

    # Set longitude bounds for plot (full zonal coverage)
    lon_min = -180
    lon_max = 180

    # Set latitude bounds based on hemisphere
    if HEM == 'sh':
        lat_min = -90
        lat_max = -65
    elif HEM =='nh':
        lat_min = 65
        lat_max = 90

    # Define plot proection based on hempisphere
    if HEM == 'sh':
        projection = ccrs.SouthPolarStereo()
    elif HEM == 'nh':
        projection = ccrs.NorthPolarStereo()

    # Define data-to-plot's coordinate reference system
    # NOTE, used for 'crs' and 'transform' cartopy parameters
    crs = ccrs.PlateCarree()

    # Set color map
    cmap = cmo.cm.thermal  # red blue colormap from cmocean

    # Saturate colormap to show small values
    vmin = 10
    vmax = 0.05
    
    # Initialize subplots
    fig, axs = plt.subplots(
        nrows = 1,
        ncols = 2,
        figsize = (6,3),
        subplot_kw = {'projection': projection},
        constrained_layout = True
    )

    # Plot left plot; zonal evaluation
    axs[0].set_extent([lon_min, lon_max, lat_min, lat_max], crs = crs)
    axs[0].coastlines
    # Plot pcolormesh plot
    pcm_0 = axs[0].pcolormesh(
        lon, lat, u_data,
        transform = crs,
        cmap = cmap, 
        # vmin = vmin, 
        # vmax = vmax
    )
    # axs[0].set_title("zonal")
    # Add colorbar
    plt.colorbar(pcm_0, ax = axs[0], orientation = 'vertical')

    # Plot right plot; meridional evaluation
    axs[1].set_extent([lon_min, lon_max, lat_min, lat_max], crs = crs)
    axs[1].coastlines
    # Plot pcolormesh plot
    pcm_1 = axs[1].pcolormesh(
        lon, lat, v_data,
        transform = crs,
        cmap = cmap, 
        # vmin = vmin, 
        # vmax = vmax
    )
    # axs[1].set_title("meridional")
    # Add colorbar
    plt.colorbar(pcm_1, ax = axs[1], orientation = 'vertical')

    # Add title to plot
    fig.suptitle(f"{metric}", fontweight = 'bold')

    # Format with tight layout
    fig.tight_layout

    # Add text with means
    fig.text(0, -0.05, f"mean zonal {metric}: {np.nanmean(u_data):.4f}")
    fig.text(0.5, -0.05, f"mean meridional {metric}: {np.nanmean(v_data):.4f}")

    # # Define filemane for figure
    # fnam = f"{metric}_{MODEL_STR}_{TIMESTAMP_MODEL}.png"

    # # Save figure
    # plt.savefig(os.path.join(PATH_DEST, fnam), bbox_inches = 'tight')

    return

# %%
plot_metric(vartrue_u, vartrue_v, lon, lat, 'vartrue')

# %%
var_thresh = 0.05

var_mask = (vartrue_u < var_thresh) | (vartrue_v < var_thresh)

vartrue_u_thresh = np.where(var_mask, vartrue_u, np.nan)
vartrue_v_thresh = np.where(var_mask, vartrue_v, np.nan)

plot_metric(vartrue_u_thresh, vartrue_v_thresh, lon, lat, f'vartrue < {var_thresh}')

# %%
r_bar = np.nanmean(ri_t0, axis = 0)

# %%
plot_metric2(r_bar, r_bar, lon, lat, 'r_bar')

# %%
r_raw_bar = np.nanmean(r_raw, axis = 0)

# %%
plot_metric2(r_raw_bar, r_raw_bar, lon, lat, 'r_raw_bar')

# %%
# Count number of days with raw ice conentration equal to zero at each gridpoint
zero_days = np.sum(ci_raw_t0 == 0, axis = 0)

plot_metric2(zero_days, zero_days, lon, lat, 'zero_days')

# %%
# Zero days greater than 20 percent
zero_days_gr20 = zero_days > nt*.2
print(zero_days_gr20)

# %%
plot_metric2(zero_days_gr20, zero_days, lon, lat, 'zero_days > 20%')

# %%
# Zero days greater than 50 percent
zero_days_gr50 = zero_days > nt*.5
plot_metric2(zero_days_gr50, zero_days, lon, lat, 'zero_days > 50%')

# %%
# Zero days greater than 75 percent
zero_days_gr75 = zero_days > nt*.75
plot_metric2(zero_days_gr75, zero_days, lon, lat, 'zero_days > 75%')

# %%
np.shape(zero_days_gr75)

# %%
mask = zero_days_gr75
string = 'true_var[zero_days_gr75]'
fill_val = np.nan

plot_metric(
    np.where(mask, vartrue_u, fill_val),
    np.where(mask, vartrue_u, fill_val),
    lon, lat, string
)

# %%
zero_days_gr80 = zero_days > nt*.80
mask = zero_days_gr80
string = 'true_var[zero_days_gr80]'
fill_val = np.nan

plot_metric(
    np.where(mask, vartrue_u, fill_val),
    np.where(mask, vartrue_u, fill_val),
    lon, lat, string
)

# %%
zero_days_gr90 = zero_days > nt*.90
mask = zero_days_gr90
string = 'true_var[zero_days_gr90]'
fill_val = np.nan

plot_metric(
    np.where(mask, vartrue_u, fill_val),
    np.where(mask, vartrue_u, fill_val),
    lon, lat, string
)

# %%
zero_days_gr95 = zero_days > nt*.95
mask = zero_days_gr95
string = 'true_var[zero_days_gr95]'
fill_val = np.nan

plot_metric(
    np.where(mask, vartrue_u, fill_val),
    np.where(mask, vartrue_u, fill_val),
    lon, lat, string
)

# %%
# TODO autocorrelation, decorralation scale, effective degrees of freedom at each point

### (3b) ###

# Compute the decorrelation scale

# Initialize array of decorrelation scales
L = N

T_eff = np.ones(L)

# Iterate through L's from 0 to N
for i in range(L):
    # Integrate covariance with bounds -L to L
    # T_eff[i]=np.sum(xcov[L+1-i:L-1+i])/xcov[L-1]
    T_eff[i]=np.sum(xcov[L+1-i:L-1+i])/xcov[L-1]

plt.plot(T_eff)

plt.ylabel('Decorrelation Scale')
plt.xlabel('lag')

plt.show()

# Use max effecitve decorrelation scale
T_eff_max = np.max(T_eff)
print(f'The effective decorrleation scale is {int(T_eff_max)}')

# Calculate degrees of freedom, conservatively
N_eff = (N / T_eff_max)
print(f'There are {int(N_eff)} effective degrees of freedom')
